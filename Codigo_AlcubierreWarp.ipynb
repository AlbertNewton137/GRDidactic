# %%
import sympy as smp
import time

def Christoffel(i,j,k):
    s = 0
    for a in range(n):
        s+=1/2*g_inv[a,i]*(smp.diff(g[a,j],coord[k])+smp.diff(g[a,k],coord[j])-smp.diff(g[j,k],coord[a]))
    return s

def Riemann(i,j,k,l):
    p=smp.diff(ch[i,j,l],coord[k])-(smp.diff(ch[i,j,k],coord[l]))
    s=0
    for o in range(n):
        s+=ch[i,o,k]*ch[o,j,l]-(ch[i,o,l]*ch[o,j,k])
    return smp.simplify(p+s)

def Ricci(i,j):
    s=0
    for o in range(n):
        s+=riem[o,i,o,j]
    return s

def Einstein(i,j):
    s=-1/2*g[i,j]*er+ricci[i,j]
    return s

# %%
coord = smp.symbols('t r theta phi')
beta = smp.symbols('beta',cls=smp.Function)
beta=beta(coord[0],coord[1])

n = len(coord)

g= smp.Matrix([[0 for i in range(n)] for i in range(n)])
ch=  smp.MutableDenseNDimArray([[[0 for i in range(n)] for i in range(n)] for i in range(n)])
riem = smp.MutableDenseNDimArray([[[[0 for i in range(n)] for i in range(n)] for i in range(n)]for i in range(n)])
ricci = smp.Matrix([[0 for i in range(n)] for i in range(n)])
einstein = smp.Matrix([[0 for i in range(n)] for i in range(n)])

g[0,0]=-(1-beta**2)
g[0,1]=-beta
g[1,0]=-beta
g[1,1]=1
g[2,2]=coord[1]**2
g[3,3]=coord[1]**2*(smp.sin(coord[2])**2)


g_inv = smp.simplify(g.inv())


gcovariante = smp.symbols(fr'g_alpha_beta')
gcontravariante = smp.symbols(fr'g^alpha^beta')

display(smp.Eq(gcovariante,g,evaluate=False))
display(smp.Eq(gcontravariante,g_inv,evaluate=False))
# Out:
# Eq(g_alpha_beta, Matrix([
# [beta(t, r)**2 - 1, -beta(t, r),    0,                  0],
# [      -beta(t, r),           1,    0,                  0],
# [                0,           0, r**2,                  0],
# [                0,           0,    0, r**2*sin(theta)**2]]))
# Eq(g^alpha^beta, Matrix([
# [         -1,       -beta(t, r),       0,                      0],
# [-beta(t, r), 1 - beta(t, r)**2,       0,                      0],
# [          0,                 0, r**(-2),                      0],
# [          0,                 0,       0, 1/(r**2*sin(theta)**2)]]))

# %%
# %%time
#Simbolos de Cristoffel
for a in range(n):
    for b in range(n):
        for c in range(n):
            ch[a,b,c]=Christoffel(a, b, c)
            if ch[a, b, c] != 0:
                gamma = smp.Symbol(fr'\Gamma_{coord[b]}_{coord[c]}^{coord[a]}')
                display(smp.Eq(gamma,smp.simplify(ch[a, b, c]),evaluate=False))
# Out:
# Eq(\Gamma_t_t^t, 1.0*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(\Gamma_t_r^t, -1.0*beta(t, r)*Derivative(beta(t, r), r))
# Eq(\Gamma_r_t^t, -1.0*beta(t, r)*Derivative(beta(t, r), r))
# Eq(\Gamma_r_r^t, 1.0*Derivative(beta(t, r), r))
# Eq(\Gamma_theta_theta^t, 1.0*r*beta(t, r))
# Eq(\Gamma_phi_phi^t, 1.0*r*beta(t, r)*sin(theta)**2)
# Eq(\Gamma_t_t^r, 1.0*beta(t, r)**3*Derivative(beta(t, r), r) - 1.0*beta(t, r)*Derivative(beta(t, r), r) - 1.0*Derivative(beta(t, r), t))
# Eq(\Gamma_t_r^r, -1.0*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(\Gamma_r_t^r, -1.0*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(\Gamma_r_r^r, 1.0*beta(t, r)*Derivative(beta(t, r), r))
# Eq(\Gamma_theta_theta^r, 1.0*r*(beta(t, r)**2 - 1))
# Eq(\Gamma_phi_phi^r, 1.0*r*(beta(t, r)**2 - 1)*sin(theta)**2)
# Eq(\Gamma_r_theta^theta, 1.0/r)
# Eq(\Gamma_theta_r^theta, 1.0/r)
# Eq(\Gamma_phi_phi^theta, -0.5*sin(2*theta))
# Eq(\Gamma_r_phi^phi, 1.0/r)
# Eq(\Gamma_theta_phi^phi, 1.0/tan(theta))
# Eq(\Gamma_phi_r^phi, 1.0/r)
# Eq(\Gamma_phi_theta^phi, 1.0/tan(theta))
# CPU times: user 819 ms, sys: 20.9 ms, total: 840 ms
# Wall time: 2.24 s

# %%
# %%time
#Tensor de Riemann
for a in range(n):
    for b in range(n):
        for c in range(n):
            for d in range(n):
                riem[a,b,c,d]=Riemann(a, b, c,d)
                if riem[a, b, c, d] != 0:
                    R = smp.Symbol(fr'R_{coord[b]}_{coord[c]}_{coord[d]}^{coord[a]}')
                    display(smp.Eq(R,riem[a, b, c,d],evaluate=False))
# Out:
# Eq(R_t_t_r^t, 1.0*(-beta(t, r)*Derivative(beta(t, r), (r, 2)) - Derivative(beta(t, r), r)**2 - Derivative(beta(t, r), r, t))*beta(t, r))
# Eq(R_t_r_t^t, 1.0*(beta(t, r)*Derivative(beta(t, r), (r, 2)) + Derivative(beta(t, r), r)**2 + Derivative(beta(t, r), r, t))*beta(t, r))
# Eq(R_r_t_r^t, 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R_r_r_t^t, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R_theta_t_theta^t, 1.0*r*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t)))
# Eq(R_theta_theta_t^t, 1.0*r*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t)))
# Eq(R_phi_t_phi^t, 1.0*r*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_phi_phi_t^t, 1.0*r*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_t_t_r^r, -1.0*beta(t, r)**3*Derivative(beta(t, r), (r, 2)) - 1.0*beta(t, r)**2*Derivative(beta(t, r), r)**2 - 1.0*beta(t, r)**2*Derivative(beta(t, r), r, t) + 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R_t_r_t^r, 1.0*beta(t, r)**3*Derivative(beta(t, r), (r, 2)) + 1.0*beta(t, r)**2*Derivative(beta(t, r), r)**2 + 1.0*beta(t, r)**2*Derivative(beta(t, r), r, t) - 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R_r_t_r^r, 1.0*(beta(t, r)*Derivative(beta(t, r), (r, 2)) + Derivative(beta(t, r), r)**2 + Derivative(beta(t, r), r, t))*beta(t, r))
# Eq(R_r_r_t^r, 1.0*(-beta(t, r)*Derivative(beta(t, r), (r, 2)) - Derivative(beta(t, r), r)**2 - Derivative(beta(t, r), r, t))*beta(t, r))
# Eq(R_theta_t_theta^r, 1.0*r*beta(t, r)*Derivative(beta(t, r), t))
# Eq(R_theta_r_theta^r, 1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_theta_theta_t^r, -1.0*r*beta(t, r)*Derivative(beta(t, r), t))
# Eq(R_theta_theta_r^r, -1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_phi_t_phi^r, 1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), t))
# Eq(R_phi_r_phi^r, 1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_phi_t^r, -1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), t))
# Eq(R_phi_phi_r^r, -1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_t_t_theta^theta, 1.0*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/r)
# Eq(R_t_r_theta^theta, 1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_t_theta_t^theta, 1.0*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/r)
# Eq(R_t_theta_r^theta, -1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_t_theta^theta, 1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_r_theta^theta, -1.0*beta(t, r)*Derivative(beta(t, r), r)/r)
# Eq(R_r_theta_t^theta, -1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_theta_r^theta, 1.0*beta(t, r)*Derivative(beta(t, r), r)/r)
# Eq(R_phi_theta_phi^theta, 1.0*beta(t, r)**2*sin(theta)**2)
# Eq(R_phi_phi_theta^theta, -1.0*beta(t, r)**2*sin(theta)**2)
# Eq(R_t_t_phi^phi, 1.0*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/r)
# Eq(R_t_r_phi^phi, 1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_t_phi_t^phi, 1.0*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/r)
# Eq(R_t_phi_r^phi, -1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_t_phi^phi, 1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_r_phi^phi, -1.0*beta(t, r)*Derivative(beta(t, r), r)/r)
# Eq(R_r_phi_t^phi, -1.0*beta(t, r)**2*Derivative(beta(t, r), r)/r)
# Eq(R_r_phi_r^phi, 1.0*beta(t, r)*Derivative(beta(t, r), r)/r)
# Eq(R_theta_theta_phi^phi, -1.0*beta(t, r)**2)
# Eq(R_theta_phi_theta^phi, 1.0*beta(t, r)**2)
# CPU times: user 4.19 s, sys: 109 ms, total: 4.3 s
# Wall time: 8.98 s

# %%
# %%time
#Componentes Rienman totalmente contravariantes
riem_cont = smp.MutableDenseNDimArray([[[[0 for i in range(n)] for i in range(n)] for i in range(n)]for i in range(n)])

for a in range(n):
    for b in range(n):
        for c in range(n):
            for d in range(n):
                suma=0
                for bb in range(n):
                    for cc in range(n):
                        for dd in range(n):
                            suma+=g_inv[b,bb]*g_inv[c,cc]*g_inv[d,dd]*riem[a,bb,cc,dd]
                riem_cont[a,b,c,d]=smp.simplify(suma)
                if riem_cont[a,b,c,d] != 0:
                    R = smp.Symbol(fr'R^{coord[a]}^{coord[b]}^{coord[c]}^{coord[d]}')
                    display(smp.Eq(R,riem_cont[a,b,c,d],evaluate=False))
# Out:
# Eq(R^t^r^t^r, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R^t^r^r^t, 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R^t^theta^t^theta, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/r**3)
# Eq(R^t^theta^r^theta, -1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^t^theta^theta^t, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/r**3)
# Eq(R^t^theta^theta^r, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^t^phi^t^phi, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/(r**3*sin(theta)**2))
# Eq(R^t^phi^r^phi, -1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^t^phi^phi^t, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/(r**3*sin(theta)**2))
# Eq(R^t^phi^phi^r, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^r^t^t^r, 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R^r^t^r^t, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R^r^theta^t^theta, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^r^theta^r^theta, 1.0*(-(beta(t, r)**2 - 1)*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^r^theta^theta^t, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^r^theta^theta^r, 1.0*((beta(t, r)**2 - 1)*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^r^phi^t^phi, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^r^phi^r^phi, 1.0*(-(beta(t, r)**2 - 1)*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^r^phi^phi^t, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^r^phi^phi^r, 1.0*((beta(t, r)**2 - 1)*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^theta^t^t^theta, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/r**3)
# Eq(R^theta^t^r^theta, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^theta^t^theta^t, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/r**3)
# Eq(R^theta^t^theta^r, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^theta^r^t^theta, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^theta^r^r^theta, 1.0*(beta(t, r)**2*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), t) - Derivative(beta(t, r), r))*beta(t, r)/r**3)
# Eq(R^theta^r^theta^t, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/r**3)
# Eq(R^theta^r^theta^r, 1.0*(-beta(t, r)**2*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), t) + Derivative(beta(t, r), r))*beta(t, r)/r**3)
# Eq(R^theta^phi^theta^phi, 1.0*beta(t, r)**2/(r**6*sin(theta)**2))
# Eq(R^theta^phi^phi^theta, -1.0*beta(t, r)**2/(r**6*sin(theta)**2))
# Eq(R^phi^t^t^phi, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))/(r**3*sin(theta)**2))
# Eq(R^phi^t^r^phi, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^t^phi^t, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))/(r**3*sin(theta)**2))
# Eq(R^phi^t^phi^r, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^r^t^phi, 1.0*(beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^r^r^phi, 1.0*(beta(t, r)**2*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), t) - Derivative(beta(t, r), r))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^r^phi^t, 1.0*(-beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^r^phi^r, 1.0*(-beta(t, r)**2*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), t) + Derivative(beta(t, r), r))*beta(t, r)/(r**3*sin(theta)**2))
# Eq(R^phi^theta^theta^phi, -1.0*beta(t, r)**2/(r**6*sin(theta)**2))
# Eq(R^phi^theta^phi^theta, 1.0*beta(t, r)**2/(r**6*sin(theta)**2))
# CPU times: user 5.37 s, sys: 123 ms, total: 5.49 s
# Wall time: 10.9 s

# %%
# %%time
#Componentes Rienman totalmente covariantes
riem_cov = smp.MutableDenseNDimArray([[[[0 for i in range(n)] for i in range(n)] for i in range(n)]for i in range(n)])
for a in range(n):
    for b in range(n):
        for c in range(n):
            for d in range(n):
                suma=0
                for aa in range(n):
                    suma+=g[a,aa]*riem[aa,b,c,d]
                riem_cov[a,b,c,d]=smp.simplify(suma)
                if riem_cov[a,b,c,d] != 0:
                    R = smp.Symbol(fr'R_{coord[a]}_{coord[b]}_{coord[c]}_{coord[d]}')
                    display(smp.Eq(R,riem_cov[a,b,c,d],evaluate=False))
# Out:
# Eq(R_t_r_t_r, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R_t_r_r_t, 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R_t_theta_t_theta, 1.0*r*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t)))
# Eq(R_t_theta_r_theta, -1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_t_theta_theta_t, 1.0*r*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t)))
# Eq(R_t_theta_theta_r, 1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_t_phi_t_phi, 1.0*r*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_t_phi_r_phi, -1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_t_phi_phi_t, 1.0*r*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_t_phi_phi_r, 1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_r_t_t_r, 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t))
# Eq(R_r_t_r_t, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t))
# Eq(R_r_theta_t_theta, -1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_r_theta_r_theta, 1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_r_theta_theta_t, 1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_r_theta_theta_r, -1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_r_phi_t_phi, -1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_r_phi_r_phi, 1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_r_phi_phi_t, 1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_r_phi_phi_r, -1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_theta_t_t_theta, 1.0*r*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t)))
# Eq(R_theta_t_r_theta, 1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_theta_t_theta_t, 1.0*r*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t)))
# Eq(R_theta_t_theta_r, -1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_theta_r_t_theta, 1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_theta_r_r_theta, -1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_theta_r_theta_t, -1.0*r*beta(t, r)**2*Derivative(beta(t, r), r))
# Eq(R_theta_r_theta_r, 1.0*r*beta(t, r)*Derivative(beta(t, r), r))
# Eq(R_theta_phi_theta_phi, 1.0*r**2*beta(t, r)**2*sin(theta)**2)
# Eq(R_theta_phi_phi_theta, -1.0*r**2*beta(t, r)**2*sin(theta)**2)
# Eq(R_phi_t_t_phi, 1.0*r*(-beta(t, r)**3*Derivative(beta(t, r), r) + beta(t, r)*Derivative(beta(t, r), r) + Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_phi_t_r_phi, 1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_t_phi_t, 1.0*r*(beta(t, r)**3*Derivative(beta(t, r), r) - beta(t, r)*Derivative(beta(t, r), r) - Derivative(beta(t, r), t))*sin(theta)**2)
# Eq(R_phi_t_phi_r, -1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_r_t_phi, 1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_r_r_phi, -1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_r_phi_t, -1.0*r*beta(t, r)**2*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_r_phi_r, 1.0*r*beta(t, r)*sin(theta)**2*Derivative(beta(t, r), r))
# Eq(R_phi_theta_theta_phi, -1.0*r**2*beta(t, r)**2*sin(theta)**2)
# Eq(R_phi_theta_phi_theta, 1.0*r**2*beta(t, r)**2*sin(theta)**2)
# CPU times: user 2.1 s, sys: 50.2 ms, total: 2.15 s
# Wall time: 2.28 s

# %%
# %%time
#Tensor de Ricci
for a in range(n):
    for b in range(n):
        ricci[a,b]=Ricci(a,b)
        if ricci[a,b]!=0:
            Ri = smp.Symbol(fr'R_{coord[a]}_{coord[b]}')
            display(smp.Eq(Ri,smp.simplify(ricci[a,b]),evaluate=False))
# Out:
# Eq(R_t_t, (1.0*r*(beta(t, r)**3*Derivative(beta(t, r), (r, 2)) + beta(t, r)**2*Derivative(beta(t, r), r)**2 + beta(t, r)**2*Derivative(beta(t, r), r, t) - beta(t, r)*Derivative(beta(t, r), (r, 2)) - Derivative(beta(t, r), r)**2 - Derivative(beta(t, r), r, t)) + 2.0*beta(t, r)**3*Derivative(beta(t, r), r) - 2.0*beta(t, r)*Derivative(beta(t, r), r) - 2.0*Derivative(beta(t, r), t))/r)
# Eq(R_t_r, (-1.0*r*(beta(t, r)*Derivative(beta(t, r), (r, 2)) + Derivative(beta(t, r), r)**2 + Derivative(beta(t, r), r, t)) - 2.0*beta(t, r)*Derivative(beta(t, r), r))*beta(t, r)/r)
# Eq(R_r_t, (-1.0*r*(beta(t, r)*Derivative(beta(t, r), (r, 2)) + Derivative(beta(t, r), r)**2 + Derivative(beta(t, r), r, t)) - 2.0*beta(t, r)*Derivative(beta(t, r), r))*beta(t, r)/r)
# Eq(R_r_r, (1.0*r*(beta(t, r)*Derivative(beta(t, r), (r, 2)) + Derivative(beta(t, r), r)**2 + Derivative(beta(t, r), r, t)) + 2.0*beta(t, r)*Derivative(beta(t, r), r))/r)
# Eq(R_theta_theta, 2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 1.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)
# Eq(R_phi_phi, (2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 1.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)*sin(theta)**2)
# CPU times: user 643 ms, sys: 11.8 ms, total: 655 ms
# Wall time: 673 ms

# %%
# %%time
#tensor de Ricci contravariante
ricci_cont= smp.Matrix([[0 for i in range(n)] for i in range(n)])
for a in range(n):
    for b in range(n):
        suma=0
        for aa in range(n):
            for bb in range(n):
                suma+=g_inv[a,aa]*ricci[aa,bb]*g_inv[bb,b]
        ricci_cont[a,b] = smp.simplify(suma)
        if ricci_cont[a,b]!=0:
            Ri = smp.Symbol(fr'R^{coord[a]}^{coord[b]}')
            display(smp.Eq(Ri,ricci_cont[a,b],evaluate=False))
# Out:
# Eq(R^t^t, -1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*Derivative(beta(t, r), r)**2 - 1.0*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)*Derivative(beta(t, r), r)/r - 2.0*Derivative(beta(t, r), t)/r)
# Eq(R^t^r, 1.0*(-1.0*r*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*r*Derivative(beta(t, r), r)**2 - 1.0*r*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)*Derivative(beta(t, r), r) - 2.0*Derivative(beta(t, r), t))*beta(t, r)/r)
# Eq(R^r^t, 1.0*(-1.0*r*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*r*Derivative(beta(t, r), r)**2 - 1.0*r*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)*Derivative(beta(t, r), r) - 2.0*Derivative(beta(t, r), t))*beta(t, r)/r)
# Eq(R^r^r, -1.0*beta(t, r)**3*Derivative(beta(t, r), (r, 2)) - 1.0*beta(t, r)**2*Derivative(beta(t, r), r)**2 - 1.0*beta(t, r)**2*Derivative(beta(t, r), r, t) + 1.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 1.0*Derivative(beta(t, r), r)**2 + 1.0*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)**3*Derivative(beta(t, r), r)/r - 2.0*beta(t, r)**2*Derivative(beta(t, r), t)/r + 2.0*beta(t, r)*Derivative(beta(t, r), r)/r)
# Eq(R^theta^theta, 1.0*(2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 1.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)/r**4)
# Eq(R^phi^phi, 1.0*(2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 1.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)/(r**4*sin(theta)**2))
# CPU times: user 1.02 s, sys: 14.7 ms, total: 1.03 s
# Wall time: 1.04 s

# %%
# %%time
#Escalar de Ricci
er=0
for a in range(n):
    for b in range(n):
        er+=g_inv[a,b]*ricci[a,b]
ER=smp.symbols('R')
display(smp.Eq(ER,smp.simplify(er),evaluate=False))
# Out:
# Eq(R, 2.0*beta(t, r)*Derivative(beta(t, r), (r, 2)) + 2.0*Derivative(beta(t, r), r)**2 + 2.0*Derivative(beta(t, r), r, t) + 8.0*beta(t, r)*Derivative(beta(t, r), r)/r + 4.0*Derivative(beta(t, r), t)/r + 2.0*beta(t, r)**2/r**2)
# CPU times: user 243 ms, sys: 3.18 ms, total: 246 ms
# Wall time: 248 ms

# %%
# %time
#Escalar de Kretschmann
ek=0
for a in range(n):
    for b in range(n):
        for c in range(n):
            for d in range(n):
                ek+=(riem_cov[a,b,c,d])*(riem_cont[a,b,c,d])
K=smp.symbols('K')
display(smp.Eq(K,smp.simplify(ek),evaluate=False))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs
# Eq(K, 4.0*beta(t, r)**2*Derivative(beta(t, r), (r, 2))**2 + 8.0*beta(t, r)*Derivative(beta(t, r), r)**2*Derivative(beta(t, r), (r, 2)) + 8.0*beta(t, r)*Derivative(beta(t, r), (r, 2))*Derivative(beta(t, r), r, t) + 4.0*Derivative(beta(t, r), r)**4 + 8.0*Derivative(beta(t, r), r)**2*Derivative(beta(t, r), r, t) + 4.0*Derivative(beta(t, r), r, t)**2 + 16.0*beta(t, r)**2*Derivative(beta(t, r), r)**2/r**2 + 16.0*beta(t, r)*Derivative(beta(t, r), r)*Derivative(beta(t, r), t)/r**2 + 8.0*Derivative(beta(t, r), t)**2/r**2 + 4.0*beta(t, r)**4/r**4)

# %%
# %%time
#Tensor de Einstein
for a in range(n):
    for b in range(n):
        einstein[a,b]=Einstein(a,b)
        if einstein[a,b]!=0:
            G = smp.Symbol(fr'G_{coord[a]}_{coord[b]}')
            display(smp.Eq(G,smp.simplify(einstein[a,b]), evaluate=False ))
# Out:
# Eq(G_t_t, 1.0*(-2.0*r*beta(t, r)**2*Derivative(beta(t, r), r) - 2.0*r*beta(t, r)*Derivative(beta(t, r), t) + 2.0*r*Derivative(beta(t, r), r) - 1.0*beta(t, r)**3 + 1.0*beta(t, r))*beta(t, r)/r**2)
# Eq(G_t_r, 1.0*(2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 2.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)*beta(t, r)/r**2)
# Eq(G_r_t, 1.0*(2.0*r*beta(t, r)*Derivative(beta(t, r), r) + 2.0*r*Derivative(beta(t, r), t) + 1.0*beta(t, r)**2)*beta(t, r)/r**2)
# Eq(G_r_r, 1.0*(-2.0*r*beta(t, r)*Derivative(beta(t, r), r) - 2.0*r*Derivative(beta(t, r), t) - 1.0*beta(t, r)**2)/r**2)
# Eq(G_theta_theta, r*(-1.0*r*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*r*Derivative(beta(t, r), r)**2 - 1.0*r*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)*Derivative(beta(t, r), r) - 1.0*Derivative(beta(t, r), t)))
# Eq(G_phi_phi, r*(-1.0*r*beta(t, r)*Derivative(beta(t, r), (r, 2)) - 1.0*r*Derivative(beta(t, r), r)**2 - 1.0*r*Derivative(beta(t, r), r, t) - 2.0*beta(t, r)*Derivative(beta(t, r), r) - 1.0*Derivative(beta(t, r), t))*sin(theta)**2)
# CPU times: user 1.48 s, sys: 14.1 ms, total: 1.5 s
# Wall time: 1.52 s

# %%
# %%time
#Geodésicas
L=smp.symbols('lambda')
for a in range(n):
    w1=0
    w2=0
    w1=smp.diff(coord[a],L,L,evaluate=False)
    for b in range(n):
        for c in range(n):
            w2+=smp.simplify(ch[a,c,b])*smp.diff(coord[c],L,evaluate=False)*smp.diff(coord[b],L,evaluate=False)
    display(coord[a])
    display(smp.Eq(w1+w2,0,evaluate=False))
# Out:
# t
# Eq(1.0*r*beta(t, r)*sin(theta)**2*Derivative(phi, lambda)**2 + 1.0*r*beta(t, r)*Derivative(theta, lambda)**2 + 1.0*beta(t, r)**2*Derivative(t, lambda)**2*Derivative(beta(t, r), r) - 2.0*beta(t, r)*Derivative(r, lambda)*Derivative(t, lambda)*Derivative(beta(t, r), r) + 1.0*Derivative(r, lambda)**2*Derivative(beta(t, r), r) + Derivative(t, (lambda, 2)), 0)
# r
# Eq(1.0*r*(beta(t, r)**2 - 1)*sin(theta)**2*Derivative(phi, lambda)**2 + 1.0*r*(beta(t, r)**2 - 1)*Derivative(theta, lambda)**2 + (1.0*beta(t, r)**3*Derivative(beta(t, r), r) - 1.0*beta(t, r)*Derivative(beta(t, r), r) - 1.0*Derivative(beta(t, r), t))*Derivative(t, lambda)**2 - 2.0*beta(t, r)**2*Derivative(r, lambda)*Derivative(t, lambda)*Derivative(beta(t, r), r) + 1.0*beta(t, r)*Derivative(r, lambda)**2*Derivative(beta(t, r), r) + Derivative(r, (lambda, 2)), 0)
# theta
# Eq(-0.5*sin(2*theta)*Derivative(phi, lambda)**2 + Derivative(theta, (lambda, 2)) + 2.0*Derivative(r, lambda)*Derivative(theta, lambda)/r, 0)
# phi
# Eq(Derivative(phi, (lambda, 2)) + 2.0*Derivative(phi, lambda)*Derivative(theta, lambda)/tan(theta) + 2.0*Derivative(phi, lambda)*Derivative(r, lambda)/r, 0)
# CPU times: user 346 ms, sys: 8.21 ms, total: 354 ms
# Wall time: 364 ms
